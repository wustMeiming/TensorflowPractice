# %%
import pygame
import random
from pygame.locals import *
import numpy as np
from collections import deque
import tensorflow as tf # http://blog.topspeedsnail.com/archives/10116
import cv2 # http://blog.topspeedsnail.com/archives/4755

# %%
BLACK = (0  ,   0,   0)
WHITE = (255, 255, 255)

# %%
SCREEN_SIZE = [320, 400]
BAR_SIZE    = [50, 5]
BALL_SIZE   = [15, 15]

# %%
# 神经网络的输出
MOVE_STAY  = [1, 0, 0]
MOVE_LEFT  = [0, 1, 0]
MOVE_RIGHT = [0, 0, 1]

# %%
class Game(object):
    def __init__(self):
        pygame.init()
        self.clock = pygame.time.Clock()
        self.screen = pygame.display.set_mode(SCREEN_SIZE)
        pygame.display.set_caption('Simple Game')
        
        self.ball_pos_x = SCREEN_SIZE[0]//2 - BALL_SIZE[0]/2
        self.ball_pos_y = SCREEN_SIZE[1]//2 - BALL_SIZE[1]/2
        
        self.ball_dir_x = -1 # -1 = left 1 = right
        self.ball_dir_y = -1 # -1 = up   1 = down
        self.ball_pos = pygame.Rect(self.ball_pos_x, self.ball_pos_y, BALL_SIZE[0], BALL_SIZE[1])
        
        self.bar_pos_x = SCREEN_SIZE[0]//2 - BAR_SIZE[0]//2
        self.bar_pos = pygame.Rect(self.bar_pos_x, SCREEN_SIZE[1] - BAR_SIZE[1], BAR_SIZE[0], BAR_SIZE[1])
    
    # action是MOVE_STAY、MOVE_LEFT、MOVE_RIGHT
    # ai控制棒子左右移动；返回游戏界面像素数和对应的奖励。(像素->奖励->强化棒子往奖励高的方向移动)
    def step(self, action):
        if action == MOVE_LEFT:
            self.bar_pos_x = self.bar_pos_x - 2
        elif action == MOVE_RIGHT:
            self.bar_pos_x = self.bar_pos_x + 2
        else:
            pass
        
        if self.bar_pos_x < 0:
            self.bar_pos_x = 0
        if self.bar_pos_x > SCREEN_SIZE[0] - BAR_SIZE[0]:
            self.bar_pos_x = SCREEN_SIZE[0] - BAR_SIZE[0]
        
        self.screen.fill(BLACK)
        self.bar_pos.left = self.bar_pos_x
        pygame.draw.rect(self.screen, WHITE, self.bar_pos)
        
        self.ball_pos.left += self.ball_dir_x * 2
        self.ball_pos.bottom += self.ball_dir_y * 3
        pygame.draw.rect(self.screen, WHITE, self.ball_pos)
        
        if self.ball_pos.top <= 0 or self.ball_pos.bottom >= (SCREEN_SIZE[1] - BAR_SIZE[1]+1):
            self.ball_dir_y = self.ball_dir_y * -1
        if self.ball_pos.left <= 0 or self.ball_pos.right >= (SCREEN_SIZE[0]):
            self.ball_dir_x = self.ball_dir_x * -1
            
        reward = 0
        if self.bar_pos.top <= self.ball_pos.bottom and (self.bar_pos.left < self.ball_pos.right and self.bar_pos.right > self.ball_pos.left):
            reward = 1 # 击中奖励
        elif self.bar_pos.top <= self.ball_pos.bottom and (self.bar_pos.left > self.ball_pos.right or self.bar_pos.right < self.ball_pos.left):
            reward = -1 # 没击中惩罚
        
        # 获得游戏界面要素
        screen_image = pygame.surfarray.array3d(pygame.display.get_surface())
        pygame.display.update()
        # 返回游戏界面像素和对应的奖励
        return reward, screen_image

# %%
# Learning_rate
LEARNING_RATE = 0.99

# 更新梯度
INITIAL_EPSILON = 1.0
FINAL_EPSILON = 0.05

# 测试观测次数
EXPLORE = 500000
OBSERVE = 50000

# 存储过往经验大小
REPLAY_MEMORY = 500000

# %%
BATCH = 100

output = 3 #  输出层神经元数。代表3种操作-MOVE_STAY:[1, 0, 0]  MOVE_LEFT:[0, 1, 0]  MOVE_RIGHT:[0, 0, 1]
input_image = tf.placeholder(tf.float32, [None, 80, 100, 4]) # 游戏像素
action = tf.placeholder(tf.float32, [None, output]) # 操作

# %%
# 定义CNN-卷积神经网络 参考:http://blog.topspeedsnail.com/archives/10451
def convolutional_neural_network(input_image):
    weights = {'w_conv1':tf.Variable(tf.zeros([8, 8, 4, 32])),
              'w_conv2':tf.Variable(tf.zeros([4, 4, 32, 64])),
              'w_conv3':tf.Variable(tf.zeros([3, 3, 64, 64])),
              'w_fc4':tf.Variable(tf.zeros([3456, 784])),
              'w_out':tf.Variable(tf.zeros([784, output]))}
    
    biases = {'b_conv1':tf.Variable(tf.zeros([32])),
             'b_conv2':tf.Variable(tf.zeros([64])),
             'b_conv3':tf.Variable(tf.zeros([64])),
             'b_fc4':tf.Variable(tf.zeros([784])),
             'b_out':tf.Variable(tf.zeros([output]))}
    
    conv1 = tf.nn.relu(tf.nn.conv2d(input_image, weights['w_conv1'], strides=[1,4,4,1], padding='VALID') + biases['b_conv1'])
    conv2 = tf.nn.relu(tf.nn.conv2d(conv1, weights['w_conv2'], strides=[1,2,2,1], padding='VALID') + biases['b_conv2'])
    conv3 = tf.nn.relu(tf.nn.conv2d(conv2, weights['w_conv3'], strides=[1,1,1,1], padding='VALID') + biases['b_conv3'])
    conv3_flat = tf.reshape(conv3, [-1, 3456])
    fc4 = tf.nn.relu(tf.matmul(conv3_flat, weights['w_fc4']) + biases['b_fc4'])
    
    output_layer = tf.matmul(fc4, weights['w_out']) + biases['b_out']
    return output_layer

# %%
# 深度强化学习入门: https://www.nervanasys.com/demystifying-deep-reinforcement-learning/
# 训练神经网络
def train_neural_network(input_image):
    predict_action = convolutional_neural_network(input_image)
    
    argmax = tf.placeholder(tf.float32, [None, output])
    gt = tf.placeholder(tf.float32, [None])
    
    action = tf.reduce_sum(tf.multiply(predict_action, argmax), reduction_indices=1)
    cost = tf.reduce_mean(tf.square(action - gt))
    optimizer = tf.train.AdamOptimizer(1e-6).minimize(cost)
    
    game = Game()
    D = deque()
    
    _, image = game.step(MOVE_STAY)
    # 转换为灰度值
    image = cv2.cvtColor(cv2.resize(image, (100, 80)), cv2.COLOR_BGR2GRAY)
    # 转换为二值
    ret, image = cv2.threshold(image, 1, 255, cv2.THRESH_BINARY)
    input_image_data = np.stack((image, image, image, image), axis = 2)
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        saver = tf.train.Saver()
        
        n = 0
        epsilon = INITIAL_EPSILON
        
        while True:
            action_t = predict_action.eval(feed_dict={input_image:[input_image_data]})[0]
            
            argmax_t = np.zeros([output], dtype=np.int)
            if(random.random() <= INITIAL_EPSILON):
                maxIndex = random.randrange(output)
            else:
                maxIndex = np.argmax(action_t)
            argmax_t[maxIndex] = 1
            if epsilon > FINAL_EPSILON:
                epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE
            
            #for event in pygame.event.get():  macOS需要事件循环，否则白屏
            #    if event.type == QUIT:
            #        pygame.quit()
            #        sys.exit()
            reward, image = game.step(list(argmax_t))
            
            image = cv2.cvtColor(cv2.resize(image, (100, 80)), cv2.COLOR_BGR2GRAY)
            ret, image = cv2.threshold(image, 1, 255, cv2.THRESH_BINARY)
            image = np.reshape(image, (80, 100, 1))
            input_image_data1 = np.append(image, input_image_data[:,:,0:3], axis=2)
            
            D.append((input_image_data, argmax_t, reward, input_image_data1))
            
            if len(D) > REPLAY_MEMORY:
                D.popleft()
            
            if n > OBSERVE:
                minibatch = random.sample(D, BATCH)
                input_image_data_batch = [d[0] for d in minibatch]
                argmax_batch = [d[1] for d in minibatch]
                reward_batch = [d[2] for d in minibatch]
                input_image_data1_batch = [d[3] for d in minibatch]
                
                gt_batch = []
                
                out_batch = predict_action.eval(feed_dict = {input_image:input_image_data1_batch})
                
                for i in range(len(minibatch)):
                    gt_batch.append(reward_batch[i] + LEARNING_RATE * np.max(out_batch[i]))
                
                optimizer.run(feed_dict = {gt:gt_batch, argmax:argmax_batch, input_image:input_image_data_batch})
            
            input_image_data = input_image_data1
            n = n + 1
            
            if n % 10000 == 0:
                saver.save(sess, 'game.cpk', global_step = n) # 保存模型
            
            print(n, 'eepsilon:', epsilon, ' ', 'action:', maxIndex, ' ', 'reward:', reward)

# %%
train_neural_network(input_image)
# Out:
# 1 eepsilon: 0.9999981   action: 2   reward: 0
# 2 eepsilon: 0.9999962   action: 0   reward: 0
# 3 eepsilon: 0.9999943   action: 2   reward: 0
# 4 eepsilon: 0.9999924   action: 1   reward: 0
# 5 eepsilon: 0.9999905   action: 1   reward: 0
# 6 eepsilon: 0.9999886   action: 1   reward: 0
# 7 eepsilon: 0.9999867   action: 0   reward: 0
# 8 eepsilon: 0.9999848   action: 1   reward: 0
# 9 eepsilon: 0.9999829   action: 2   reward: 0
# 10 eepsilon: 0.999981   action: 0   reward: 0
# 11 eepsilon: 0.9999791   action: 0   reward: 0
# 12 eepsilon: 0.9999772   action: 0   reward: 0
# 13 eepsilon: 0.9999753   action: 1   reward: 0
# 14 eepsilon: 0.9999734   action: 1   reward: 0
# 15 eepsilon: 0.9999715   action: 0   reward: 0
# 16 eepsilon: 0.9999696   action: 1   reward: 0
# 17 eepsilon: 0.9999677   action: 0   reward: 0
# 18 eepsilon: 0.9999658   action: 2   reward: 0
# 19 eepsilon: 0.9999639   action: 0   reward: 0
# 20 eepsilon: 0.999962   action: 2   reward: 0
# 21 eepsilon: 0.9999601   action: 2   reward: 0
# 22 eepsilon: 0.9999582   action: 1   reward: 0
# 23 eepsilon: 0.9999563   action: 0   reward: 0
# 24 eepsilon: 0.9999544   action: 2   reward: 0
# 25 eepsilon: 0.9999525   action: 0   reward: 0
# 26 eepsilon: 0.9999506   action: 0   reward: 0
# 27 eepsilon: 0.9999487   action: 1   reward: 0
# 28 eepsilon: 0.9999468   action: 0   reward: 0
# 29 eepsilon: 0.9999449   action: 0   reward: 0
# 30 eepsilon: 0.999943   action: 1   reward: 0
# 31 eepsilon: 0.9999411   action: 2   reward: 0
# 32 eepsilon: 0.9999392   action: 2   reward: 0
# 33 eepsilon: 0.9999373   action: 1   reward: 0
# 34 eepsilon: 0.9999354   action: 0   reward: 0
# 35 eepsilon: 0.9999335   action: 1   reward: 0
# 36 eepsilon: 0.9999316   action: 0   reward: 0
# 37 eepsilon: 0.9999297   action: 1   reward: 0
# 38 eepsilon: 0.9999278   action: 1   reward: 0
# 39 eepsilon: 0.9999259   action: 0   reward: 0
# 40 eepsilon: 0.999924   action: 2   reward: 0
# 41 eepsilon: 0.9999221   action: 0   reward: 0
# 42 eepsilon: 0.9999202   action: 0   reward: 0
# 43 eepsilon: 0.9999183   action: 0   reward: 0
# 44 eepsilon: 0.9999164   action: 1   reward: 0
# 45 eepsilon: 0.9999145   action: 1   reward: 0
# 46 eepsilon: 0.9999126   action: 2   reward: 0
# 47 eepsilon: 0.9999107   action: 0   reward: 0
# 48 eepsilon: 0.9999088   action: 2   reward: 0
# 49 eepsilon: 0.9999069   action: 2   reward: 0
# 50 eepsilon: 0.999905   action: 2   reward: 0
# 51 eepsilon: 0.9999031   action: 2   reward: 0
# 52 eepsilon: 0.9999012   action: 0   reward: 0
# 53 eepsilon: 0.9998993   action: 0   reward: 0
# 54 eepsilon: 0.9998974   action: 2   reward: 0
# 55 eepsilon: 0.9998955   action: 1   reward: 0
# 56 eepsilon: 0.9998936   action: 0   reward: 0
# 57 eepsilon: 0.9998917   action: 0   reward: 0
# 58 eepsilon: 0.9998898   action: 1   reward: 0
# 59 eepsilon: 0.9998879   action: 2   reward: 0
# 60 eepsilon: 0.999886   action: 2   reward: 0
# 61 eepsilon: 0.9998841   action: 2   reward: 0
# 62 eepsilon: 0.9998822   action: 0   reward: 0
# 63 eepsilon: 0.9998803   action: 2   reward: 0
# 64 eepsilon: 0.9998784000000001   action: 1   reward: 0
# 65 eepsilon: 0.9998765000000001   action: 0   reward: 0
# 66 eepsilon: 0.9998746000000001   action: 1   reward: 0
# 67 eepsilon: 0.9998727000000001   action: 2   reward: 0
# 68 eepsilon: 0.9998708000000001   action: 2   reward: 0
# 69 eepsilon: 0.9998689000000001   action: 2   reward: 0
# 70 eepsilon: 0.9998670000000001   action: 0   reward: 0
# 71 eepsilon: 0.9998651000000001   action: 1   reward: 0
# 72 eepsilon: 0.9998632000000001   action: 0   reward: 0
# 73 eepsilon: 0.9998613000000001   action: 0   reward: 0
# 74 eepsilon: 0.9998594000000001   action: 0   reward: 0
# 75 eepsilon: 0.9998575000000001   action: 2   reward: 0
# 76 eepsilon: 0.9998556000000001   action: 1   reward: 0
# 77 eepsilon: 0.9998537000000001   action: 1   reward: 0
# 78 eepsilon: 0.9998518000000001   action: 1   reward: 0
# 79 eepsilon: 0.9998499000000001   action: 0   reward: 0
# 80 eepsilon: 0.9998480000000001   action: 0   reward: 0
# 81 eepsilon: 0.9998461000000001   action: 2   reward: 0
# 82 eepsilon: 0.9998442000000001   action: 1   reward: 0
# 83 eepsilon: 0.9998423000000001   action: 1   reward: 0
# 84 eepsilon: 0.9998404000000001   action: 1   reward: 0
# 85 eepsilon: 0.9998385000000001   action: 0   reward: 0
# 86 eepsilon: 0.9998366000000001   action: 1   reward: 0
# 87 eepsilon: 0.9998347000000001   action: 1   reward: 0
# 88 eepsilon: 0.9998328000000001   action: 1   reward: 0
# 89 eepsilon: 0.9998309000000001   action: 1   reward: 0
# 90 eepsilon: 0.9998290000000001   action: 2   reward: 0
# 91 eepsilon: 0.9998271000000001   action: 2   reward: 0
# 92 eepsilon: 0.9998252000000001   action: 1   reward: 0
# 93 eepsilon: 0.9998233000000001   action: 0   reward: 0
# 94 eepsilon: 0.9998214000000001   action: 2   reward: 0
# 95 eepsilon: 0.9998195000000001   action: 0   reward: 0
# 96 eepsilon: 0.9998176000000001   action: 1   reward: 0
# 97 eepsilon: 0.9998157000000001   action: 0   reward: 0
# 98 eepsilon: 0.9998138000000001   action: 1   reward: 0
# 99 eepsilon: 0.9998119000000001   action: 1   reward: 0
# 100 eepsilon: 0.9998100000000001   action: 1   reward: 0
# 101 eepsilon: 0.9998081000000001   action: 1   reward: 0
# 102 eepsilon: 0.9998062000000001   action: 1   reward: 0
# 103 eepsilon: 0.9998043000000001   action: 1   reward: 0
# 104 eepsilon: 0.9998024000000001   action: 2   reward: 0
# 105 eepsilon: 0.9998005000000001   action: 1   reward: 0
# 106 eepsilon: 0.9997986000000001   action: 1   reward: 0
# 107 eepsilon: 0.9997967000000001   action: 1   reward: 0
# 108 eepsilon: 0.9997948000000001   action: 1   reward: 0
# 109 eepsilon: 0.9997929000000001   action: 1   reward: 0
# 110 eepsilon: 0.9997910000000001   action: 1   reward: 0
# 111 eepsilon: 0.9997891000000001   action: 0   reward: 0
# 112 eepsilon: 0.9997872000000001   action: 1   reward: 0
# 113 eepsilon: 0.9997853000000001   action: 0   reward: 0
# 114 eepsilon: 0.9997834000000001   action: 2   reward: 0
# 115 eepsilon: 0.9997815000000001   action: 2   reward: 0
# 116 eepsilon: 0.9997796000000001   action: 2   reward: 0
# 117 eepsilon: 0.9997777000000001   action: 0   reward: 0
# 118 eepsilon: 0.9997758000000001   action: 2   reward: 0
# 119 eepsilon: 0.9997739000000001   action: 0   reward: 0
# 120 eepsilon: 0.9997720000000001   action: 1   reward: 0
# 121 eepsilon: 0.9997701000000001   action: 1   reward: 0
# 122 eepsilon: 0.9997682000000001   action: 2   reward: 0
# 123 eepsilon: 0.9997663000000001   action: 2   reward: 0
# 124 eepsilon: 0.9997644000000001   action: 0   reward: 0
# 125 eepsilon: 0.9997625000000001   action: 1   reward: 0
# 126 eepsilon: 0.9997606000000001   action: 1   reward: 0
# 127 eepsilon: 0.9997587000000001   action: 1   reward: 0
# 128 eepsilon: 0.9997568000000001   action: 2   reward: 0
# 129 eepsilon: 0.9997549000000001   action: 0   reward: 0
# 130 eepsilon: 0.9997530000000001   action: 2   reward: 0
# 131 eepsilon: 0.9997511000000001   action: 1   reward: 0
# 132 eepsilon: 0.9997492000000001   action: 0   reward: 0
# 133 eepsilon: 0.9997473000000001   action: 0   reward: 0
# 134 eepsilon: 0.9997454000000001   action: 1   reward: 0
# 135 eepsilon: 0.9997435000000001   action: 0   reward: 0
# 136 eepsilon: 0.9997416000000001   action: 2   reward: 0
# 137 eepsilon: 0.9997397000000001   action: 1   reward: 0
# 138 eepsilon: 0.9997378000000001   action: 1   reward: 0
# 139 eepsilon: 0.9997359000000001   action: 2   reward: 0
# 140 eepsilon: 0.9997340000000001   action: 2   reward: 0
# 141 eepsilon: 0.9997321000000001   action: 0   reward: 0
# 142 eepsilon: 0.9997302000000001   action: 1   reward: 0
# 143 eepsilon: 0.9997283000000001   action: 2   reward: 0
# 144 eepsilon: 0.9997264000000001   action: 2   reward: 0
# 145 eepsilon: 0.9997245000000001   action: 0   reward: 0
# 146 eepsilon: 0.9997226000000001   action: 0   reward: 0
# 147 eepsilon: 0.9997207000000001   action: 1   reward: 0
# 148 eepsilon: 0.9997188000000001   action: 2   reward: 0
# 149 eepsilon: 0.9997169000000001   action: 1   reward: 0
# 150 eepsilon: 0.9997150000000001   action: 0   reward: 0
# 151 eepsilon: 0.9997131000000001   action: 1   reward: 0
# 152 eepsilon: 0.9997112000000001   action: 2   reward: 0
# 153 eepsilon: 0.9997093000000001   action: 2   reward: 0
# 154 eepsilon: 0.9997074000000001   action: 0   reward: 0
# 155 eepsilon: 0.9997055000000001   action: 2   reward: 0
# 156 eepsilon: 0.9997036000000001   action: 0   reward: 0
# 157 eepsilon: 0.9997017000000001   action: 1   reward: 0
# 158 eepsilon: 0.9996998000000001   action: 0   reward: 0
# 159 eepsilon: 0.9996979000000001   action: 0   reward: 0
# 160 eepsilon: 0.9996960000000001   action: 1   reward: 0
# 161 eepsilon: 0.9996941000000001   action: 1   reward: 0
# 162 eepsilon: 0.9996922000000001   action: 0   reward: 0
# 163 eepsilon: 0.9996903000000001   action: 0   reward: 0
# 164 eepsilon: 0.9996884000000001   action: 0   reward: 0
# 165 eepsilon: 0.9996865000000001   action: 2   reward: 0
# 166 eepsilon: 0.9996846000000001   action: 0   reward: 0
# 167 eepsilon: 0.9996827000000001   action: 0   reward: 0
# 168 eepsilon: 0.9996808000000001   action: 2   reward: 0
# 169 eepsilon: 0.9996789000000001   action: 0   reward: 0
# 170 eepsilon: 0.9996770000000001   action: 2   reward: 0
# 171 eepsilon: 0.9996751000000001   action: 0   reward: 0
# 172 eepsilon: 0.9996732000000002   action: 1   reward: 0
# 173 eepsilon: 0.9996713000000002   action: 0   reward: 0
# 174 eepsilon: 0.9996694000000002   action: 1   reward: 0
# 175 eepsilon: 0.9996675000000002   action: 0   reward: 0
# 176 eepsilon: 0.9996656000000002   action: 1   reward: 0
# 177 eepsilon: 0.9996637000000002   action: 1   reward: 0
# 178 eepsilon: 0.9996618000000002   action: 1   reward: 0
# 179 eepsilon: 0.9996599000000002   action: 0   reward: 0
# 180 eepsilon: 0.9996580000000002   action: 0   reward: 0
# 181 eepsilon: 0.9996561000000002   action: 2   reward: 0
# 182 eepsilon: 0.9996542000000002   action: 1   reward: 0
# 183 eepsilon: 0.9996523000000002   action: 1   reward: 0
# 184 eepsilon: 0.9996504000000002   action: 2   reward: 0
# 185 eepsilon: 0.9996485000000002   action: 1   reward: 0
# 186 eepsilon: 0.9996466000000002   action: 0   reward: 0
# 187 eepsilon: 0.9996447000000002   action: 2   reward: 0
# 188 eepsilon: 0.9996428000000002   action: 1   reward: 0
# 189 eepsilon: 0.9996409000000002   action: 0   reward: 0
# 190 eepsilon: 0.9996390000000002   action: 0   reward: -1
# 191 eepsilon: 0.9996371000000002   action: 0   reward: 0
# 192 eepsilon: 0.9996352000000002   action: 0   reward: 0
# 193 eepsilon: 0.9996333000000002   action: 2   reward: 0
# 194 eepsilon: 0.9996314000000002   action: 2   reward: 0
# 195 eepsilon: 0.9996295000000002   action: 1   reward: 0
# 196 eepsilon: 0.9996276000000002   action: 1   reward: 0
# 197 eepsilon: 0.9996257000000002   action: 2   reward: 0
# 198 eepsilon: 0.9996238000000002   action: 0   reward: 0
# 199 eepsilon: 0.9996219000000002   action: 0   reward: 0
# 200 eepsilon: 0.9996200000000002   action: 2   reward: 0
# 201 eepsilon: 0.9996181000000002   action: 0   reward: 0
# 202 eepsilon: 0.9996162000000002   action: 1   reward: 0
# 203 eepsilon: 0.9996143000000002   action: 0   reward: 0
# 204 eepsilon: 0.9996124000000002   action: 0   reward: 0
# 205 eepsilon: 0.9996105000000002   action: 2   reward: 0
# 206 eepsilon: 0.9996086000000002   action: 2   reward: 0
# 207 eepsilon: 0.9996067000000002   action: 1   reward: 0
# 208 eepsilon: 0.9996048000000002   action: 2   reward: 0
# 209 eepsilon: 0.9996029000000002   action: 1   reward: 0
# 210 eepsilon: 0.9996010000000002   action: 2   reward: 0
# 211 eepsilon: 0.9995991000000002   action: 0   reward: 0
# 212 eepsilon: 0.9995972000000002   action: 2   reward: 0
# 213 eepsilon: 0.9995953000000002   action: 2   reward: 0
# 214 eepsilon: 0.9995934000000002   action: 0   reward: 0
# 215 eepsilon: 0.9995915000000002   action: 1   reward: 0
# 216 eepsilon: 0.9995896000000002   action: 1   reward: 0
# 217 eepsilon: 0.9995877000000002   action: 0   reward: 0
# 218 eepsilon: 0.9995858000000002   action: 0   reward: 0
# 219 eepsilon: 0.9995839000000002   action: 2   reward: 0
# 220 eepsilon: 0.9995820000000002   action: 2   reward: 0
# 221 eepsilon: 0.9995801000000002   action: 2   reward: 0
# 222 eepsilon: 0.9995782000000002   action: 2   reward: 0
# 223 eepsilon: 0.9995763000000002   action: 1   reward: 0
# 224 eepsilon: 0.9995744000000002   action: 2   reward: 0
# 225 eepsilon: 0.9995725000000002   action: 1   reward: 0
# 226 eepsilon: 0.9995706000000002   action: 2   reward: 0
# 227 eepsilon: 0.9995687000000002   action: 1   reward: 0
# 228 eepsilon: 0.9995668000000002   action: 0   reward: 0
# 229 eepsilon: 0.9995649000000002   action: 1   reward: 0
# 230 eepsilon: 0.9995630000000002   action: 2   reward: 0
# 231 eepsilon: 0.9995611000000002   action: 0   reward: 0
# 232 eepsilon: 0.9995592000000002   action: 0   reward: 0
# 233 eepsilon: 0.9995573000000002   action: 2   reward: 0
# 234 eepsilon: 0.9995554000000002   action: 1   reward: 0
# 235 eepsilon: 0.9995535000000002   action: 1   reward: 0
# 236 eepsilon: 0.9995516000000002   action: 0   reward: 0
# 237 eepsilon: 0.9995497000000002   action: 2   reward: 0
# 238 eepsilon: 0.9995478000000002   action: 2   reward: 0
# 239 eepsilon: 0.9995459000000002   action: 0   reward: 0
# 240 eepsilon: 0.9995440000000002   action: 0   reward: 0
# 241 eepsilon: 0.9995421000000002   action: 0   reward: 0
# 242 eepsilon: 0.9995402000000002   action: 2   reward: 0
# 243 eepsilon: 0.9995383000000002   action: 1   reward: 0
# 244 eepsilon: 0.9995364000000002   action: 2   reward: 0
# 245 eepsilon: 0.9995345000000002   action: 0   reward: 0
# 246 eepsilon: 0.9995326000000002   action: 0   reward: 0
# 247 eepsilon: 0.9995307000000002   action: 0   reward: 0
# 248 eepsilon: 0.9995288000000002   action: 0   reward: 0
# 249 eepsilon: 0.9995269000000002   action: 1   reward: 0
# 250 eepsilon: 0.9995250000000002   action: 2   reward: 0
# 251 eepsilon: 0.9995231000000002   action: 1   reward: 0
# 252 eepsilon: 0.9995212000000002   action: 1   reward: 0
# 253 eepsilon: 0.9995193000000002   action: 1   reward: 0
# 254 eepsilon: 0.9995174000000002   action: 1   reward: 0
# 255 eepsilon: 0.9995155000000002   action: 2   reward: 0
# 256 eepsilon: 0.9995136000000002   action: 1   reward: 0
# 257 eepsilon: 0.9995117000000002   action: 2   reward: 0
# 258 eepsilon: 0.9995098000000002   action: 1   reward: 0
# 259 eepsilon: 0.9995079000000002   action: 0   reward: 0
# 260 eepsilon: 0.9995060000000002   action: 1   reward: 0
# 261 eepsilon: 0.9995041000000002   action: 0   reward: 0
# 262 eepsilon: 0.9995022000000002   action: 1   reward: 0
# 263 eepsilon: 0.9995003000000002   action: 2   reward: 0
# 264 eepsilon: 0.9994984000000002   action: 2   reward: 0
# 265 eepsilon: 0.9994965000000002   action: 0   reward: 0
# 266 eepsilon: 0.9994946000000002   action: 2   reward: 0
# 267 eepsilon: 0.9994927000000002   action: 0   reward: 0
# 268 eepsilon: 0.9994908000000002   action: 2   reward: 0
# 269 eepsilon: 0.9994889000000002   action: 2   reward: 0
# 270 eepsilon: 0.9994870000000002   action: 2   reward: 0
# 271 eepsilon: 0.9994851000000002   action: 2   reward: 0
# 272 eepsilon: 0.9994832000000002   action: 2   reward: 0
# 273 eepsilon: 0.9994813000000002   action: 1   reward: 0
# 274 eepsilon: 0.9994794000000002   action: 0   reward: 0
# 275 eepsilon: 0.9994775000000002   action: 1   reward: 0
# 276 eepsilon: 0.9994756000000002   action: 1   reward: 0
# 277 eepsilon: 0.9994737000000002   action: 0   reward: 0
# 278 eepsilon: 0.9994718000000002   action: 0   reward: 0
# 279 eepsilon: 0.9994699000000002   action: 1   reward: 0
# 280 eepsilon: 0.9994680000000002   action: 2   reward: 0
# 281 eepsilon: 0.9994661000000002   action: 2   reward: 0
# 282 eepsilon: 0.9994642000000002   action: 2   reward: 0
# 283 eepsilon: 0.9994623000000002   action: 1   reward: 0
# 284 eepsilon: 0.9994604000000002   action: 0   reward: 0
# 285 eepsilon: 0.9994585000000002   action: 2   reward: 0
# 286 eepsilon: 0.9994566000000003   action: 2   reward: 0
# 287 eepsilon: 0.9994547000000003   action: 1   reward: 0
# 288 eepsilon: 0.9994528000000003   action: 0   reward: 0
# 289 eepsilon: 0.9994509000000003   action: 0   reward: 0
# 290 eepsilon: 0.9994490000000003   action: 2   reward: 0
# 291 eepsilon: 0.9994471000000003   action: 1   reward: 0
# 292 eepsilon: 0.9994452000000003   action: 1   reward: 0
# 293 eepsilon: 0.9994433000000003   action: 1   reward: 0
# 294 eepsilon: 0.9994414000000003   action: 1   reward: 0
# 295 eepsilon: 0.9994395000000003   action: 1   reward: 0
# 296 eepsilon: 0.9994376000000003   action: 0   reward: 0
# 297 eepsilon: 0.9994357000000003   action: 1   reward: 0
# 298 eepsilon: 0.9994338000000003   action: 0   reward: 0
# 299 eepsilon: 0.9994319000000003   action: 0   reward: 0
# 300 eepsilon: 0.9994300000000003   action: 0   reward: 0
# 301 eepsilon: 0.9994281000000003   action: 2   reward: 0
# 302 eepsilon: 0.9994262000000003   action: 0   reward: 0
# 303 eepsilon: 0.9994243000000003   action: 0   reward: 0
# 304 eepsilon: 0.9994224000000003   action: 1   reward: 0
# 305 eepsilon: 0.9994205000000003   action: 0   reward: 0
# 306 eepsilon: 0.9994186000000003   action: 1   reward: 0
# 307 eepsilon: 0.9994167000000003   action: 2   reward: 0
# 308 eepsilon: 0.9994148000000003   action: 1   reward: 0
# 309 eepsilon: 0.9994129000000003   action: 1   reward: 0
# 310 eepsilon: 0.9994110000000003   action: 1   reward: 0
# 311 eepsilon: 0.9994091000000003   action: 0   reward: 0
# 312 eepsilon: 0.9994072000000003   action: 2   reward: 0
# 313 eepsilon: 0.9994053000000003   action: 2   reward: 0
# 314 eepsilon: 0.9994034000000003   action: 2   reward: 0
# 315 eepsilon: 0.9994015000000003   action: 2   reward: 0
# 316 eepsilon: 0.9993996000000003   action: 2   reward: 0
# 317 eepsilon: 0.9993977000000003   action: 2   reward: 0
# 318 eepsilon: 0.9993958000000003   action: 2   reward: 0
# 319 eepsilon: 0.9993939000000003   action: 0   reward: 0
# 320 eepsilon: 0.9993920000000003   action: 2   reward: 0
# 321 eepsilon: 0.9993901000000003   action: 2   reward: 0
# 322 eepsilon: 0.9993882000000003   action: 2   reward: 0
# 323 eepsilon: 0.9993863000000003   action: 1   reward: 0
# 324 eepsilon: 0.9993844000000003   action: 2   reward: 0
# 325 eepsilon: 0.9993825000000003   action: 1   reward: 0
# 326 eepsilon: 0.9993806000000003   action: 0   reward: 0
# 327 eepsilon: 0.9993787000000003   action: 1   reward: 0
# 328 eepsilon: 0.9993768000000003   action: 2   reward: 0
# 329 eepsilon: 0.9993749000000003   action: 1   reward: 0
# 330 eepsilon: 0.9993730000000003   action: 1   reward: 0
# 331 eepsilon: 0.9993711000000003   action: 2   reward: 0
# 332 eepsilon: 0.9993692000000003   action: 0   reward: 0
# 333 eepsilon: 0.9993673000000003   action: 2   reward: 0
# 334 eepsilon: 0.9993654000000003   action: 1   reward: 0
# 335 eepsilon: 0.9993635000000003   action: 0   reward: 0
# 336 eepsilon: 0.9993616000000003   action: 2   reward: 0
# 337 eepsilon: 0.9993597000000003   action: 1   reward: 0
# 338 eepsilon: 0.9993578000000003   action: 0   reward: 0
# 339 eepsilon: 0.9993559000000003   action: 0   reward: 0
# 340 eepsilon: 0.9993540000000003   action: 0   reward: 0
# 341 eepsilon: 0.9993521000000003   action: 0   reward: 0
# 342 eepsilon: 0.9993502000000003   action: 1   reward: 0
# 343 eepsilon: 0.9993483000000003   action: 2   reward: 0
# 344 eepsilon: 0.9993464000000003   action: 0   reward: 0
# 345 eepsilon: 0.9993445000000003   action: 2   reward: 0
# 346 eepsilon: 0.9993426000000003   action: 1   reward: 0
# 347 eepsilon: 0.9993407000000003   action: 2   reward: 0
# 348 eepsilon: 0.9993388000000003   action: 2   reward: 0
# 349 eepsilon: 0.9993369000000003   action: 0   reward: 0
# 350 eepsilon: 0.9993350000000003   action: 1   reward: 0
# 351 eepsilon: 0.9993331000000003   action: 0   reward: 0
# 352 eepsilon: 0.9993312000000003   action: 0   reward: 0
# 353 eepsilon: 0.9993293000000003   action: 2   reward: 0
# 354 eepsilon: 0.9993274000000003   action: 1   reward: 0
# 355 eepsilon: 0.9993255000000003   action: 1   reward: 0
# 356 eepsilon: 0.9993236000000003   action: 1   reward: 0
# 357 eepsilon: 0.9993217000000003   action: 1   reward: 0
# 358 eepsilon: 0.9993198000000003   action: 0   reward: 0
# 359 eepsilon: 0.9993179000000003   action: 2   reward: 0
# 360 eepsilon: 0.9993160000000003   action: 1   reward: 0
# 361 eepsilon: 0.9993141000000003   action: 2   reward: 0
# 362 eepsilon: 0.9993122000000003   action: 2   reward: 0
# 363 eepsilon: 0.9993103000000003   action: 1   reward: 0
# 364 eepsilon: 0.9993084000000003   action: 1   reward: 0
# 365 eepsilon: 0.9993065000000003   action: 2   reward: 0
# 366 eepsilon: 0.9993046000000003   action: 0   reward: 0
# 367 eepsilon: 0.9993027000000003   action: 0   reward: 0
# 368 eepsilon: 0.9993008000000003   action: 1   reward: 0
# 369 eepsilon: 0.9992989000000003   action: 0   reward: 0
# 370 eepsilon: 0.9992970000000003   action: 0   reward: 0
# 371 eepsilon: 0.9992951000000003   action: 2   reward: 0
# 372 eepsilon: 0.9992932000000003   action: 2   reward: 0
# 373 eepsilon: 0.9992913000000003   action: 2   reward: 0
# 374 eepsilon: 0.9992894000000003   action: 0   reward: 0
# 375 eepsilon: 0.9992875000000003   action: 2   reward: 0
# 376 eepsilon: 0.9992856000000003   action: 2   reward: 0
# 377 eepsilon: 0.9992837000000003   action: 0   reward: 0
# 378 eepsilon: 0.9992818000000003   action: 0   reward: 0
# 379 eepsilon: 0.9992799000000003   action: 1   reward: 0
# 380 eepsilon: 0.9992780000000003   action: 0   reward: 0
# 381 eepsilon: 0.9992761000000003   action: 0   reward: 0
# 382 eepsilon: 0.9992742000000003   action: 1   reward: 0
# 383 eepsilon: 0.9992723000000003   action: 2   reward: 0
# 384 eepsilon: 0.9992704000000003   action: 1   reward: 0
# 385 eepsilon: 0.9992685000000003   action: 2   reward: 0
# 386 eepsilon: 0.9992666000000003   action: 0   reward: 0
# 387 eepsilon: 0.9992647000000003   action: 1   reward: 0
# 388 eepsilon: 0.9992628000000003   action: 1   reward: 0
# 389 eepsilon: 0.9992609000000003   action: 2   reward: 0
# 390 eepsilon: 0.9992590000000003   action: 0   reward: 0
# 391 eepsilon: 0.9992571000000003   action: 2   reward: 0
# 392 eepsilon: 0.9992552000000003   action: 1   reward: 0
# 393 eepsilon: 0.9992533000000003   action: 1   reward: 0
# 394 eepsilon: 0.9992514000000003   action: 2   reward: 0
# 395 eepsilon: 0.9992495000000003   action: 0   reward: 0
# 396 eepsilon: 0.9992476000000003   action: 2   reward: 0
# 397 eepsilon: 0.9992457000000003   action: 2   reward: 0
# 398 eepsilon: 0.9992438000000003   action: 0   reward: 0
# 399 eepsilon: 0.9992419000000003   action: 2   reward: 0
# 400 eepsilon: 0.9992400000000004   action: 2   reward: 0
# 401 eepsilon: 0.9992381000000004   action: 2   reward: 0
# 402 eepsilon: 0.9992362000000004   action: 2   reward: 0
# 403 eepsilon: 0.9992343000000004   action: 2   reward: 0
# 404 eepsilon: 0.9992324000000004   action: 1   reward: 0
# 405 eepsilon: 0.9992305000000004   action: 0   reward: 0
# 406 eepsilon: 0.9992286000000004   action: 1   reward: 0
# 407 eepsilon: 0.9992267000000004   action: 2   reward: 0
# 408 eepsilon: 0.9992248000000004   action: 0   reward: 0
# 409 eepsilon: 0.9992229000000004   action: 0   reward: 0
# 410 eepsilon: 0.9992210000000004   action: 0   reward: 0
# 411 eepsilon: 0.9992191000000004   action: 1   reward: 0
# 412 eepsilon: 0.9992172000000004   action: 2   reward: 0
# 413 eepsilon: 0.9992153000000004   action: 1   reward: 0
# 414 eepsilon: 0.9992134000000004   action: 2   reward: 0
# 415 eepsilon: 0.9992115000000004   action: 0   reward: 0
# 416 eepsilon: 0.9992096000000004   action: 0   reward: 0
# 417 eepsilon: 0.9992077000000004   action: 1   reward: 0
# 418 eepsilon: 0.9992058000000004   action: 0   reward: 0
# 419 eepsilon: 0.9992039000000004   action: 0   reward: 0
# 420 eepsilon: 0.9992020000000004   action: 1   reward: 0
# 421 eepsilon: 0.9992001000000004   action: 1   reward: 0
# 422 eepsilon: 0.9991982000000004   action: 2   reward: 0
# 423 eepsilon: 0.9991963000000004   action: 0   reward: 0
# 424 eepsilon: 0.9991944000000004   action: 0   reward: 0
# 425 eepsilon: 0.9991925000000004   action: 2   reward: 0
# 426 eepsilon: 0.9991906000000004   action: 2   reward: 0
# 427 eepsilon: 0.9991887000000004   action: 0   reward: 0
# 428 eepsilon: 0.9991868000000004   action: 2   reward: 0
# 429 eepsilon: 0.9991849000000004   action: 0   reward: 0
# 430 eepsilon: 0.9991830000000004   action: 0   reward: 0
# 431 eepsilon: 0.9991811000000004   action: 2   reward: 0
# 432 eepsilon: 0.9991792000000004   action: 2   reward: 0
# 433 eepsilon: 0.9991773000000004   action: 0   reward: 0
# 434 eepsilon: 0.9991754000000004   action: 1   reward: 0
# 435 eepsilon: 0.9991735000000004   action: 2   reward: 0
# 436 eepsilon: 0.9991716000000004   action: 2   reward: 0
# 437 eepsilon: 0.9991697000000004   action: 0   reward: 0
# 438 eepsilon: 0.9991678000000004   action: 0   reward: 0
# 439 eepsilon: 0.9991659000000004   action: 1   reward: 0
# 440 eepsilon: 0.9991640000000004   action: 1   reward: 0
# 441 eepsilon: 0.9991621000000004   action: 0   reward: 0
# 442 eepsilon: 0.9991602000000004   action: 2   reward: 0
# 443 eepsilon: 0.9991583000000004   action: 1   reward: 0
# 444 eepsilon: 0.9991564000000004   action: 1   reward: 1
# 445 eepsilon: 0.9991545000000004   action: 2   reward: 0
# 446 eepsilon: 0.9991526000000004   action: 1   reward: 0
# 447 eepsilon: 0.9991507000000004   action: 1   reward: 0
# 448 eepsilon: 0.9991488000000004   action: 2   reward: 0
# 449 eepsilon: 0.9991469000000004   action: 0   reward: 0
# 450 eepsilon: 0.9991450000000004   action: 1   reward: 0
# 451 eepsilon: 0.9991431000000004   action: 1   reward: 0
# 452 eepsilon: 0.9991412000000004   action: 0   reward: 0
# 453 eepsilon: 0.9991393000000004   action: 2   reward: 0
# 454 eepsilon: 0.9991374000000004   action: 0   reward: 0
# 455 eepsilon: 0.9991355000000004   action: 0   reward: 0
# 456 eepsilon: 0.9991336000000004   action: 2   reward: 0
# 457 eepsilon: 0.9991317000000004   action: 0   reward: 0
# 458 eepsilon: 0.9991298000000004   action: 0   reward: 0
# 459 eepsilon: 0.9991279000000004   action: 0   reward: 0
# 460 eepsilon: 0.9991260000000004   action: 1   reward: 0
# 461 eepsilon: 0.9991241000000004   action: 1   reward: 0
# 462 eepsilon: 0.9991222000000004   action: 2   reward: 0
# 463 eepsilon: 0.9991203000000004   action: 1   reward: 0
# 464 eepsilon: 0.9991184000000004   action: 0   reward: 0
# 465 eepsilon: 0.9991165000000004   action: 0   reward: 0
# 466 eepsilon: 0.9991146000000004   action: 1   reward: 0
# 467 eepsilon: 0.9991127000000004   action: 1   reward: 0
# 468 eepsilon: 0.9991108000000004   action: 1   reward: 0
# 469 eepsilon: 0.9991089000000004   action: 2   reward: 0
# 470 eepsilon: 0.9991070000000004   action: 2   reward: 0
# 471 eepsilon: 0.9991051000000004   action: 2   reward: 0
# 472 eepsilon: 0.9991032000000004   action: 0   reward: 0
# 473 eepsilon: 0.9991013000000004   action: 0   reward: 0
# 474 eepsilon: 0.9990994000000004   action: 0   reward: 0
# 475 eepsilon: 0.9990975000000004   action: 2   reward: 0
# 476 eepsilon: 0.9990956000000004   action: 0   reward: 0
# 477 eepsilon: 0.9990937000000004   action: 0   reward: 0
# 478 eepsilon: 0.9990918000000004   action: 1   reward: 0
# 479 eepsilon: 0.9990899000000004   action: 0   reward: 0
# 480 eepsilon: 0.9990880000000004   action: 0   reward: 0
# 481 eepsilon: 0.9990861000000004   action: 1   reward: 0
# 482 eepsilon: 0.9990842000000004   action: 2   reward: 0
# 483 eepsilon: 0.9990823000000004   action: 0   reward: 0
# 484 eepsilon: 0.9990804000000004   action: 0   reward: 0
# 485 eepsilon: 0.9990785000000004   action: 0   reward: 0
# 486 eepsilon: 0.9990766000000004   action: 1   reward: 0
# 487 eepsilon: 0.9990747000000004   action: 1   reward: 0
# 488 eepsilon: 0.9990728000000004   action: 2   reward: 0
# 489 eepsilon: 0.9990709000000004   action: 0   reward: 0
# 490 eepsilon: 0.9990690000000004   action: 0   reward: 0
# 491 eepsilon: 0.9990671000000004   action: 2   reward: 0
# 492 eepsilon: 0.9990652000000004   action: 0   reward: 0
# 493 eepsilon: 0.9990633000000004   action: 0   reward: 0
# 494 eepsilon: 0.9990614000000004   action: 0   reward: 0
# 495 eepsilon: 0.9990595000000004   action: 1   reward: 0
# 496 eepsilon: 0.9990576000000004   action: 0   reward: 0
# 497 eepsilon: 0.9990557000000004   action: 1   reward: 0
# 498 eepsilon: 0.9990538000000004   action: 2   reward: 0
# 499 eepsilon: 0.9990519000000004   action: 0   reward: 0
# 500 eepsilon: 0.9990500000000004   action: 2   reward: 0
# 501 eepsilon: 0.9990481000000004   action: 2   reward: 0
# 502 eepsilon: 0.9990462000000004   action: 2   reward: 0
# 503 eepsilon: 0.9990443000000004   action: 2   reward: 0
# 504 eepsilon: 0.9990424000000004   action: 0   reward: 0
# 505 eepsilon: 0.9990405000000004   action: 2   reward: 0
# 506 eepsilon: 0.9990386000000004   action: 2   reward: 0
# 507 eepsilon: 0.9990367000000004   action: 1   reward: 0
# 508 eepsilon: 0.9990348000000004   action: 2   reward: 0
# 509 eepsilon: 0.9990329000000004   action: 1   reward: 0
# 510 eepsilon: 0.9990310000000004   action: 2   reward: 0
# 511 eepsilon: 0.9990291000000004   action: 2   reward: 0
# 512 eepsilon: 0.9990272000000004   action: 0   reward: 0
# 513 eepsilon: 0.9990253000000004   action: 0   reward: 0
# 514 eepsilon: 0.9990234000000004   action: 0   reward: 0
# 515 eepsilon: 0.9990215000000005   action: 2   reward: 0
# 516 eepsilon: 0.9990196000000005   action: 2   reward: 0
# 517 eepsilon: 0.9990177000000005   action: 2   reward: 0
# 518 eepsilon: 0.9990158000000005   action: 2   reward: 0
# 519 eepsilon: 0.9990139000000005   action: 0   reward: 0
# 520 eepsilon: 0.9990120000000005   action: 0   reward: 0
# 521 eepsilon: 0.9990101000000005   action: 2   reward: 0
# 522 eepsilon: 0.9990082000000005   action: 0   reward: 0
# 523 eepsilon: 0.9990063000000005   action: 1   reward: 0
# 524 eepsilon: 0.9990044000000005   action: 1   reward: 0
# 525 eepsilon: 0.9990025000000005   action: 0   reward: 0
# 526 eepsilon: 0.9990006000000005   action: 0   reward: 0
# 527 eepsilon: 0.9989987000000005   action: 1   reward: 0
# 528 eepsilon: 0.9989968000000005   action: 2   reward: 0
# 529 eepsilon: 0.9989949000000005   action: 2   reward: 0
# 530 eepsilon: 0.9989930000000005   action: 0   reward: 0
# 531 eepsilon: 0.9989911000000005   action: 1   reward: 0
# 532 eepsilon: 0.9989892000000005   action: 1   reward: 0
# 533 eepsilon: 0.9989873000000005   action: 2   reward: 0
# 534 eepsilon: 0.9989854000000005   action: 0   reward: 0
# 535 eepsilon: 0.9989835000000005   action: 2   reward: 0
# 536 eepsilon: 0.9989816000000005   action: 1   reward: 0
# 537 eepsilon: 0.9989797000000005   action: 1   reward: 0
# 538 eepsilon: 0.9989778000000005   action: 2   reward: 0
# 539 eepsilon: 0.9989759000000005   action: 2   reward: 0
# 540 eepsilon: 0.9989740000000005   action: 1   reward: 0
# 541 eepsilon: 0.9989721000000005   action: 2   reward: 0
# 542 eepsilon: 0.9989702000000005   action: 1   reward: 0
# 543 eepsilon: 0.9989683000000005   action: 0   reward: 0
# 544 eepsilon: 0.9989664000000005   action: 0   reward: 0
# 545 eepsilon: 0.9989645000000005   action: 0   reward: 0
# 546 eepsilon: 0.9989626000000005   action: 0   reward: 0
# 547 eepsilon: 0.9989607000000005   action: 1   reward: 0
# 548 eepsilon: 0.9989588000000005   action: 0   reward: 0
# 549 eepsilon: 0.9989569000000005   action: 2   reward: 0
# 550 eepsilon: 0.9989550000000005   action: 1   reward: 0
# 551 eepsilon: 0.9989531000000005   action: 2   reward: 0
# 552 eepsilon: 0.9989512000000005   action: 0   reward: 0
# 553 eepsilon: 0.9989493000000005   action: 1   reward: 0
# 554 eepsilon: 0.9989474000000005   action: 1   reward: 0
# 555 eepsilon: 0.9989455000000005   action: 0   reward: 0
# 556 eepsilon: 0.9989436000000005   action: 1   reward: 0
# 557 eepsilon: 0.9989417000000005   action: 0   reward: 0
# 558 eepsilon: 0.9989398000000005   action: 0   reward: 0
# 559 eepsilon: 0.9989379000000005   action: 2   reward: 0
# 560 eepsilon: 0.9989360000000005   action: 1   reward: 0
# 561 eepsilon: 0.9989341000000005   action: 0   reward: 0
# 562 eepsilon: 0.9989322000000005   action: 2   reward: 0
# 563 eepsilon: 0.9989303000000005   action: 0   reward: 0
# 564 eepsilon: 0.9989284000000005   action: 0   reward: 0
# 565 eepsilon: 0.9989265000000005   action: 1   reward: 0
# 566 eepsilon: 0.9989246000000005   action: 2   reward: 0
# 567 eepsilon: 0.9989227000000005   action: 0   reward: 0
# 568 eepsilon: 0.9989208000000005   action: 1   reward: 0
# 569 eepsilon: 0.9989189000000005   action: 1   reward: 0
# 570 eepsilon: 0.9989170000000005   action: 0   reward: 0
# 571 eepsilon: 0.9989151000000005   action: 0   reward: 0
# 572 eepsilon: 0.9989132000000005   action: 0   reward: 0
# 573 eepsilon: 0.9989113000000005   action: 0   reward: 0
# 574 eepsilon: 0.9989094000000005   action: 0   reward: 0
# 575 eepsilon: 0.9989075000000005   action: 2   reward: 0
# 576 eepsilon: 0.9989056000000005   action: 2   reward: 0
# 577 eepsilon: 0.9989037000000005   action: 0   reward: 0
# 578 eepsilon: 0.9989018000000005   action: 0   reward: 0
# 579 eepsilon: 0.9988999000000005   action: 0   reward: 0
# 580 eepsilon: 0.9988980000000005   action: 2   reward: 0
# 581 eepsilon: 0.9988961000000005   action: 1   reward: 0
# 582 eepsilon: 0.9988942000000005   action: 1   reward: 0
# 583 eepsilon: 0.9988923000000005   action: 1   reward: 0
# 584 eepsilon: 0.9988904000000005   action: 0   reward: 0
# 585 eepsilon: 0.9988885000000005   action: 2   reward: 0
# 586 eepsilon: 0.9988866000000005   action: 2   reward: 0
# 587 eepsilon: 0.9988847000000005   action: 1   reward: 0
# 588 eepsilon: 0.9988828000000005   action: 2   reward: 0
# 589 eepsilon: 0.9988809000000005   action: 1   reward: 0
# 590 eepsilon: 0.9988790000000005   action: 0   reward: 0
# 591 eepsilon: 0.9988771000000005   action: 1   reward: 0
# 592 eepsilon: 0.9988752000000005   action: 2   reward: 0
# 593 eepsilon: 0.9988733000000005   action: 2   reward: 0
# 594 eepsilon: 0.9988714000000005   action: 1   reward: 0
# 595 eepsilon: 0.9988695000000005   action: 2   reward: 0
# 596 eepsilon: 0.9988676000000005   action: 2   reward: 0
# 597 eepsilon: 0.9988657000000005   action: 2   reward: 0
# 598 eepsilon: 0.9988638000000005   action: 0   reward: 0
# 599 eepsilon: 0.9988619000000005   action: 0   reward: 0
# 600 eepsilon: 0.9988600000000005   action: 1   reward: 0
# 601 eepsilon: 0.9988581000000005   action: 1   reward: 0
# 602 eepsilon: 0.9988562000000005   action: 1   reward: 0
# 603 eepsilon: 0.9988543000000005   action: 2   reward: 0
# 604 eepsilon: 0.9988524000000005   action: 1   reward: 0
# 605 eepsilon: 0.9988505000000005   action: 1   reward: 0
# 606 eepsilon: 0.9988486000000005   action: 1   reward: 0
# 607 eepsilon: 0.9988467000000005   action: 1   reward: 0
# 608 eepsilon: 0.9988448000000005   action: 1   reward: 0
# 609 eepsilon: 0.9988429000000005   action: 1   reward: 0
# 610 eepsilon: 0.9988410000000005   action: 1   reward: 0
# 611 eepsilon: 0.9988391000000005   action: 1   reward: 0
# 612 eepsilon: 0.9988372000000005   action: 1   reward: 0
# 613 eepsilon: 0.9988353000000005   action: 2   reward: 0
# 614 eepsilon: 0.9988334000000005   action: 0   reward: 0
# 615 eepsilon: 0.9988315000000005   action: 0   reward: 0
# 616 eepsilon: 0.9988296000000005   action: 0   reward: 0
# 617 eepsilon: 0.9988277000000005   action: 2   reward: 0
# 618 eepsilon: 0.9988258000000005   action: 0   reward: 0
# 619 eepsilon: 0.9988239000000005   action: 0   reward: 0
# 620 eepsilon: 0.9988220000000005   action: 2   reward: 0
# 621 eepsilon: 0.9988201000000005   action: 0   reward: 0
# 622 eepsilon: 0.9988182000000005   action: 1   reward: 0
# 623 eepsilon: 0.9988163000000005   action: 0   reward: 0
# 624 eepsilon: 0.9988144000000005   action: 1   reward: 0
# 625 eepsilon: 0.9988125000000005   action: 2   reward: 0
# 626 eepsilon: 0.9988106000000005   action: 0   reward: 0
# 627 eepsilon: 0.9988087000000005   action: 2   reward: 0
# 628 eepsilon: 0.9988068000000005   action: 1   reward: 0
# 629 eepsilon: 0.9988049000000006   action: 1   reward: 0
# 630 eepsilon: 0.9988030000000006   action: 0   reward: 0
# 631 eepsilon: 0.9988011000000006   action: 1   reward: 0
# 632 eepsilon: 0.9987992000000006   action: 0   reward: 0
# 633 eepsilon: 0.9987973000000006   action: 0   reward: 0
# 634 eepsilon: 0.9987954000000006   action: 1   reward: 0
# 635 eepsilon: 0.9987935000000006   action: 0   reward: 0
# 636 eepsilon: 0.9987916000000006   action: 0   reward: 0
# 637 eepsilon: 0.9987897000000006   action: 2   reward: 0
# 638 eepsilon: 0.9987878000000006   action: 0   reward: 0
# 639 eepsilon: 0.9987859000000006   action: 1   reward: 0
# 640 eepsilon: 0.9987840000000006   action: 2   reward: 0
# 641 eepsilon: 0.9987821000000006   action: 1   reward: 0
# 642 eepsilon: 0.9987802000000006   action: 0   reward: 0
# 643 eepsilon: 0.9987783000000006   action: 0   reward: 0
# 644 eepsilon: 0.9987764000000006   action: 1   reward: 0
# 645 eepsilon: 0.9987745000000006   action: 2   reward: 0
# 646 eepsilon: 0.9987726000000006   action: 0   reward: 0
# 647 eepsilon: 0.9987707000000006   action: 0   reward: 0
# 648 eepsilon: 0.9987688000000006   action: 0   reward: 0
# 649 eepsilon: 0.9987669000000006   action: 2   reward: 0
# 650 eepsilon: 0.9987650000000006   action: 2   reward: 0
# 651 eepsilon: 0.9987631000000006   action: 1   reward: 0
# 652 eepsilon: 0.9987612000000006   action: 1   reward: 0
# 653 eepsilon: 0.9987593000000006   action: 1   reward: 0
# 654 eepsilon: 0.9987574000000006   action: 1   reward: 0
# 655 eepsilon: 0.9987555000000006   action: 2   reward: 0
# 656 eepsilon: 0.9987536000000006   action: 0   reward: 0
# 657 eepsilon: 0.9987517000000006   action: 2   reward: 0
# 658 eepsilon: 0.9987498000000006   action: 2   reward: 0
# 659 eepsilon: 0.9987479000000006   action: 2   reward: 0
# 660 eepsilon: 0.9987460000000006   action: 1   reward: 0
# 661 eepsilon: 0.9987441000000006   action: 2   reward: 0
# 662 eepsilon: 0.9987422000000006   action: 2   reward: 0
# 663 eepsilon: 0.9987403000000006   action: 2   reward: 0
# 664 eepsilon: 0.9987384000000006   action: 1   reward: 0
# 665 eepsilon: 0.9987365000000006   action: 1   reward: 0
# 666 eepsilon: 0.9987346000000006   action: 0   reward: 0
# 667 eepsilon: 0.9987327000000006   action: 2   reward: 0
# 668 eepsilon: 0.9987308000000006   action: 2   reward: 0
# 669 eepsilon: 0.9987289000000006   action: 1   reward: 0
# 670 eepsilon: 0.9987270000000006   action: 1   reward: 0
# 671 eepsilon: 0.9987251000000006   action: 0   reward: 0
# 672 eepsilon: 0.9987232000000006   action: 1   reward: 0
# 673 eepsilon: 0.9987213000000006   action: 2   reward: 0
# 674 eepsilon: 0.9987194000000006   action: 0   reward: 0
# 675 eepsilon: 0.9987175000000006   action: 2   reward: 0
# 676 eepsilon: 0.9987156000000006   action: 0   reward: 0
# 677 eepsilon: 0.9987137000000006   action: 0   reward: 0
# 678 eepsilon: 0.9987118000000006   action: 1   reward: 0
# 679 eepsilon: 0.9987099000000006   action: 1   reward: 0
# 680 eepsilon: 0.9987080000000006   action: 0   reward: 0
# 681 eepsilon: 0.9987061000000006   action: 0   reward: 0
# 682 eepsilon: 0.9987042000000006   action: 2   reward: 0
# 683 eepsilon: 0.9987023000000006   action: 1   reward: 0
# 684 eepsilon: 0.9987004000000006   action: 0   reward: 0
# 685 eepsilon: 0.9986985000000006   action: 1   reward: 0
# 686 eepsilon: 0.9986966000000006   action: 1   reward: 0
# 687 eepsilon: 0.9986947000000006   action: 0   reward: 0
# 688 eepsilon: 0.9986928000000006   action: 1   reward: 0
# 689 eepsilon: 0.9986909000000006   action: 0   reward: 0
# 690 eepsilon: 0.9986890000000006   action: 1   reward: 0
# 691 eepsilon: 0.9986871000000006   action: 1   reward: 0
# 692 eepsilon: 0.9986852000000006   action: 0   reward: 0
# 693 eepsilon: 0.9986833000000006   action: 0   reward: 0
# 694 eepsilon: 0.9986814000000006   action: 0   reward: 0
# 695 eepsilon: 0.9986795000000006   action: 2   reward: 0
# 696 eepsilon: 0.9986776000000006   action: 1   reward: 0
# 697 eepsilon: 0.9986757000000006   action: 0   reward: 0
# 698 eepsilon: 0.9986738000000006   action: 0   reward: -1
# 699 eepsilon: 0.9986719000000006   action: 0   reward: 0
# 700 eepsilon: 0.9986700000000006   action: 2   reward: 0
# 701 eepsilon: 0.9986681000000006   action: 2   reward: 0
# 702 eepsilon: 0.9986662000000006   action: 0   reward: 0
# 703 eepsilon: 0.9986643000000006   action: 1   reward: 0
# 704 eepsilon: 0.9986624000000006   action: 1   reward: 0
# 705 eepsilon: 0.9986605000000006   action: 2   reward: 0
# 706 eepsilon: 0.9986586000000006   action: 2   reward: 0
# 707 eepsilon: 0.9986567000000006   action: 1   reward: 0
# 708 eepsilon: 0.9986548000000006   action: 2   reward: 0
# 709 eepsilon: 0.9986529000000006   action: 0   reward: 0
# 710 eepsilon: 0.9986510000000006   action: 2   reward: 0
# 711 eepsilon: 0.9986491000000006   action: 1   reward: 0
# 712 eepsilon: 0.9986472000000006   action: 1   reward: 0
# 713 eepsilon: 0.9986453000000006   action: 0   reward: 0
# 714 eepsilon: 0.9986434000000006   action: 0   reward: 0
# 715 eepsilon: 0.9986415000000006   action: 0   reward: 0
# 716 eepsilon: 0.9986396000000006   action: 1   reward: 0
# 717 eepsilon: 0.9986377000000006   action: 1   reward: 0
# 718 eepsilon: 0.9986358000000006   action: 0   reward: 0
# 719 eepsilon: 0.9986339000000006   action: 1   reward: 0
# 720 eepsilon: 0.9986320000000006   action: 1   reward: 0
# 721 eepsilon: 0.9986301000000006   action: 2   reward: 0
# 722 eepsilon: 0.9986282000000006   action: 2   reward: 0
# 723 eepsilon: 0.9986263000000006   action: 1   reward: 0
# 724 eepsilon: 0.9986244000000006   action: 0   reward: 0
# 725 eepsilon: 0.9986225000000006   action: 1   reward: 0
# 726 eepsilon: 0.9986206000000006   action: 1   reward: 0
# 727 eepsilon: 0.9986187000000006   action: 2   reward: 0
# 728 eepsilon: 0.9986168000000006   action: 0   reward: 0
# 729 eepsilon: 0.9986149000000006   action: 0   reward: 0
# 730 eepsilon: 0.9986130000000006   action: 2   reward: 0
# 731 eepsilon: 0.9986111000000006   action: 1   reward: 0
# 732 eepsilon: 0.9986092000000006   action: 1   reward: 0
# 733 eepsilon: 0.9986073000000006   action: 2   reward: 0
# 734 eepsilon: 0.9986054000000006   action: 0   reward: 0
# 735 eepsilon: 0.9986035000000006   action: 2   reward: 0
# 736 eepsilon: 0.9986016000000006   action: 2   reward: 0
# 737 eepsilon: 0.9985997000000006   action: 0   reward: 0
# 738 eepsilon: 0.9985978000000006   action: 2   reward: 0
# 739 eepsilon: 0.9985959000000006   action: 0   reward: 0
# 740 eepsilon: 0.9985940000000006   action: 1   reward: 0
# 741 eepsilon: 0.9985921000000006   action: 1   reward: 0
# 742 eepsilon: 0.9985902000000006   action: 2   reward: 0
# 743 eepsilon: 0.9985883000000007   action: 0   reward: 0
# 744 eepsilon: 0.9985864000000007   action: 2   reward: 0
# 745 eepsilon: 0.9985845000000007   action: 2   reward: 0
# 746 eepsilon: 0.9985826000000007   action: 0   reward: 0
# 747 eepsilon: 0.9985807000000007   action: 1   reward: 0
# 748 eepsilon: 0.9985788000000007   action: 1   reward: 0
# 749 eepsilon: 0.9985769000000007   action: 2   reward: 0
# 750 eepsilon: 0.9985750000000007   action: 0   reward: 0
# 751 eepsilon: 0.9985731000000007   action: 0   reward: 0
# 752 eepsilon: 0.9985712000000007   action: 0   reward: 0
# 753 eepsilon: 0.9985693000000007   action: 1   reward: 0
# 754 eepsilon: 0.9985674000000007   action: 2   reward: 0
# 755 eepsilon: 0.9985655000000007   action: 0   reward: 0
# 756 eepsilon: 0.9985636000000007   action: 2   reward: 0
# 757 eepsilon: 0.9985617000000007   action: 1   reward: 0
# 758 eepsilon: 0.9985598000000007   action: 0   reward: 0
# 759 eepsilon: 0.9985579000000007   action: 2   reward: 0
# 760 eepsilon: 0.9985560000000007   action: 2   reward: 0
# 761 eepsilon: 0.9985541000000007   action: 1   reward: 0
# 762 eepsilon: 0.9985522000000007   action: 2   reward: 0
# 763 eepsilon: 0.9985503000000007   action: 1   reward: 0
# 764 eepsilon: 0.9985484000000007   action: 0   reward: 0
# 765 eepsilon: 0.9985465000000007   action: 2   reward: 0
# 766 eepsilon: 0.9985446000000007   action: 2   reward: 0
# 767 eepsilon: 0.9985427000000007   action: 0   reward: 0
# 768 eepsilon: 0.9985408000000007   action: 1   reward: 0
# 769 eepsilon: 0.9985389000000007   action: 2   reward: 0
# 770 eepsilon: 0.9985370000000007   action: 2   reward: 0
# 771 eepsilon: 0.9985351000000007   action: 1   reward: 0
# 772 eepsilon: 0.9985332000000007   action: 1   reward: 0
# 773 eepsilon: 0.9985313000000007   action: 1   reward: 0
# 774 eepsilon: 0.9985294000000007   action: 1   reward: 0
# 775 eepsilon: 0.9985275000000007   action: 2   reward: 0
# 776 eepsilon: 0.9985256000000007   action: 2   reward: 0
# 777 eepsilon: 0.9985237000000007   action: 0   reward: 0
# 778 eepsilon: 0.9985218000000007   action: 1   reward: 0
# 779 eepsilon: 0.9985199000000007   action: 2   reward: 0
# 780 eepsilon: 0.9985180000000007   action: 2   reward: 0
# 781 eepsilon: 0.9985161000000007   action: 2   reward: 0
# 782 eepsilon: 0.9985142000000007   action: 0   reward: 0
# 783 eepsilon: 0.9985123000000007   action: 1   reward: 0
# 784 eepsilon: 0.9985104000000007   action: 0   reward: 0
# 785 eepsilon: 0.9985085000000007   action: 0   reward: 0
# 786 eepsilon: 0.9985066000000007   action: 0   reward: 0
# 787 eepsilon: 0.9985047000000007   action: 1   reward: 0
# 788 eepsilon: 0.9985028000000007   action: 2   reward: 0
# 789 eepsilon: 0.9985009000000007   action: 1   reward: 0
# 790 eepsilon: 0.9984990000000007   action: 0   reward: 0
# 791 eepsilon: 0.9984971000000007   action: 2   reward: 0
# 792 eepsilon: 0.9984952000000007   action: 0   reward: 0
# 793 eepsilon: 0.9984933000000007   action: 1   reward: 0
# 794 eepsilon: 0.9984914000000007   action: 0   reward: 0
# 795 eepsilon: 0.9984895000000007   action: 1   reward: 0
# 796 eepsilon: 0.9984876000000007   action: 2   reward: 0
# 797 eepsilon: 0.9984857000000007   action: 0   reward: 0
# 798 eepsilon: 0.9984838000000007   action: 2   reward: 0
# 799 eepsilon: 0.9984819000000007   action: 0   reward: 0
# 800 eepsilon: 0.9984800000000007   action: 2   reward: 0
# 801 eepsilon: 0.9984781000000007   action: 0   reward: 0
# 802 eepsilon: 0.9984762000000007   action: 0   reward: 0
# 803 eepsilon: 0.9984743000000007   action: 0   reward: 0
# 804 eepsilon: 0.9984724000000007   action: 0   reward: 0
# 805 eepsilon: 0.9984705000000007   action: 1   reward: 0
# 806 eepsilon: 0.9984686000000007   action: 0   reward: 0
# 807 eepsilon: 0.9984667000000007   action: 2   reward: 0
# 808 eepsilon: 0.9984648000000007   action: 2   reward: 0
# 809 eepsilon: 0.9984629000000007   action: 0   reward: 0
# 810 eepsilon: 0.9984610000000007   action: 1   reward: 0
# 811 eepsilon: 0.9984591000000007   action: 0   reward: 0
# 812 eepsilon: 0.9984572000000007   action: 0   reward: 0
# 813 eepsilon: 0.9984553000000007   action: 0   reward: 0
# 814 eepsilon: 0.9984534000000007   action: 2   reward: 0
# 815 eepsilon: 0.9984515000000007   action: 2   reward: 0
# 816 eepsilon: 0.9984496000000007   action: 2   reward: 0
# 817 eepsilon: 0.9984477000000007   action: 0   reward: 0
# 818 eepsilon: 0.9984458000000007   action: 0   reward: 0
# 819 eepsilon: 0.9984439000000007   action: 1   reward: 0
# 820 eepsilon: 0.9984420000000007   action: 2   reward: 0
# 821 eepsilon: 0.9984401000000007   action: 0   reward: 0
# 822 eepsilon: 0.9984382000000007   action: 1   reward: 0
# 823 eepsilon: 0.9984363000000007   action: 2   reward: 0
# 824 eepsilon: 0.9984344000000007   action: 1   reward: 0
# 825 eepsilon: 0.9984325000000007   action: 0   reward: 0
# 826 eepsilon: 0.9984306000000007   action: 2   reward: 0
# 827 eepsilon: 0.9984287000000007   action: 0   reward: 0
# 828 eepsilon: 0.9984268000000007   action: 1   reward: 0
# 829 eepsilon: 0.9984249000000007   action: 0   reward: 0
# 830 eepsilon: 0.9984230000000007   action: 0   reward: 0
# 831 eepsilon: 0.9984211000000007   action: 2   reward: 0
# 832 eepsilon: 0.9984192000000007   action: 2   reward: 0
# 833 eepsilon: 0.9984173000000007   action: 1   reward: 0
# 834 eepsilon: 0.9984154000000007   action: 1   reward: 0
# 835 eepsilon: 0.9984135000000007   action: 0   reward: 0
# 836 eepsilon: 0.9984116000000007   action: 2   reward: 0
# 837 eepsilon: 0.9984097000000007   action: 1   reward: 0
# 838 eepsilon: 0.9984078000000007   action: 0   reward: 0
# 839 eepsilon: 0.9984059000000007   action: 0   reward: 0
# 840 eepsilon: 0.9984040000000007   action: 0   reward: 0
# 841 eepsilon: 0.9984021000000007   action: 1   reward: 0
# 842 eepsilon: 0.9984002000000007   action: 1   reward: 0
# 843 eepsilon: 0.9983983000000007   action: 0   reward: 0
# 844 eepsilon: 0.9983964000000007   action: 0   reward: 0
# 845 eepsilon: 0.9983945000000007   action: 1   reward: 0
# 846 eepsilon: 0.9983926000000007   action: 2   reward: 0
# 847 eepsilon: 0.9983907000000007   action: 2   reward: 0
# 848 eepsilon: 0.9983888000000007   action: 2   reward: 0
# 849 eepsilon: 0.9983869000000007   action: 1   reward: 0
# 850 eepsilon: 0.9983850000000007   action: 1   reward: 0
# 851 eepsilon: 0.9983831000000007   action: 0   reward: 0
# 852 eepsilon: 0.9983812000000007   action: 2   reward: 0
# 853 eepsilon: 0.9983793000000007   action: 0   reward: 0
# 854 eepsilon: 0.9983774000000007   action: 1   reward: 0
# ...
# 52222 eepsilon: 0.9007782000000457   action: 1   reward: 0
# 52223 eepsilon: 0.9007763000000457   action: 2   reward: 0
# 52224 eepsilon: 0.9007744000000457   action: 1   reward: 0
# 52225 eepsilon: 0.9007725000000457   action: 1   reward: 0
# 52226 eepsilon: 0.9007706000000457   action: 1   reward: 0
# 52227 eepsilon: 0.9007687000000457   action: 0   reward: 0
# 52228 eepsilon: 0.9007668000000457   action: 0   reward: 0
# 52229 eepsilon: 0.9007649000000457   action: 1   reward: 0
# 52230 eepsilon: 0.9007630000000457   action: 1   reward: 0
# 52231 eepsilon: 0.9007611000000457   action: 2   reward: 0
# 52232 eepsilon: 0.9007592000000457   action: 1   reward: 0
# 52233 eepsilon: 0.9007573000000457   action: 0   reward: 0
# 52234 eepsilon: 0.9007554000000457   action: 0   reward: 0
# 52235 eepsilon: 0.9007535000000457   action: 1   reward: 0
# 52236 eepsilon: 0.9007516000000457   action: 1   reward: 0
# 52237 eepsilon: 0.9007497000000457   action: 0   reward: 0
# 52238 eepsilon: 0.9007478000000457   action: 2   reward: 0
# 52239 eepsilon: 0.9007459000000457   action: 0   reward: 0
# 52240 eepsilon: 0.9007440000000457   action: 1   reward: 0
# 52241 eepsilon: 0.9007421000000457   action: 2   reward: 0
# 52242 eepsilon: 0.9007402000000457   action: 2   reward: 0
# 52243 eepsilon: 0.9007383000000457   action: 1   reward: 0
# 52244 eepsilon: 0.9007364000000457   action: 0   reward: 0
# 52245 eepsilon: 0.9007345000000457   action: 0   reward: 0
# 52246 eepsilon: 0.9007326000000457   action: 0   reward: 0
# 52247 eepsilon: 0.9007307000000457   action: 1   reward: 0
# 52248 eepsilon: 0.9007288000000457   action: 1   reward: 0
# 52249 eepsilon: 0.9007269000000457   action: 1   reward: 0
# 52250 eepsilon: 0.9007250000000457   action: 1   reward: 0
# 52251 eepsilon: 0.9007231000000457   action: 0   reward: 0
# 52252 eepsilon: 0.9007212000000457   action: 2   reward: 0
# 52253 eepsilon: 0.9007193000000457   action: 2   reward: 0
# 52254 eepsilon: 0.9007174000000457   action: 1   reward: 0
# 52255 eepsilon: 0.9007155000000457   action: 0   reward: 0
# 52256 eepsilon: 0.9007136000000457   action: 1   reward: 0
# 52257 eepsilon: 0.9007117000000457   action: 1   reward: 0
# 52258 eepsilon: 0.9007098000000457   action: 1   reward: 0
# 52259 eepsilon: 0.9007079000000457   action: 1   reward: 0
# 52260 eepsilon: 0.9007060000000457   action: 0   reward: -1
# 52261 eepsilon: 0.9007041000000457   action: 0   reward: 0
# 52262 eepsilon: 0.9007022000000457   action: 2   reward: 0
# 52263 eepsilon: 0.9007003000000458   action: 2   reward: 0
# 52264 eepsilon: 0.9006984000000458   action: 0   reward: 0
# 52265 eepsilon: 0.9006965000000458   action: 1   reward: 0
# 52266 eepsilon: 0.9006946000000458   action: 0   reward: 0
# 52267 eepsilon: 0.9006927000000458   action: 1   reward: 0
# 52268 eepsilon: 0.9006908000000458   action: 2   reward: 0
# 52269 eepsilon: 0.9006889000000458   action: 2   reward: 0
# 52270 eepsilon: 0.9006870000000458   action: 2   reward: 0
# 52271 eepsilon: 0.9006851000000458   action: 1   reward: 0
# 52272 eepsilon: 0.9006832000000458   action: 0   reward: 0
# 52273 eepsilon: 0.9006813000000458   action: 1   reward: 0
# 52274 eepsilon: 0.9006794000000458   action: 0   reward: 0
# 52275 eepsilon: 0.9006775000000458   action: 2   reward: 0
# 52276 eepsilon: 0.9006756000000458   action: 1   reward: 0
# 52277 eepsilon: 0.9006737000000458   action: 2   reward: 0
# 52278 eepsilon: 0.9006718000000458   action: 2   reward: 0
# 52279 eepsilon: 0.9006699000000458   action: 1   reward: 0
# 52280 eepsilon: 0.9006680000000458   action: 1   reward: 0
# 52281 eepsilon: 0.9006661000000458   action: 1   reward: 0
# 52282 eepsilon: 0.9006642000000458   action: 1   reward: 0
# 52283 eepsilon: 0.9006623000000458   action: 2   reward: 0
# 52284 eepsilon: 0.9006604000000458   action: 0   reward: 0
# 52285 eepsilon: 0.9006585000000458   action: 2   reward: 0
# 52286 eepsilon: 0.9006566000000458   action: 1   reward: 0
# 52287 eepsilon: 0.9006547000000458   action: 0   reward: 0
# 52288 eepsilon: 0.9006528000000458   action: 1   reward: 0
# 52289 eepsilon: 0.9006509000000458   action: 0   reward: 0
# 52290 eepsilon: 0.9006490000000458   action: 0   reward: 0
# 52291 eepsilon: 0.9006471000000458   action: 1   reward: 0
# 52292 eepsilon: 0.9006452000000458   action: 2   reward: 0
# 52293 eepsilon: 0.9006433000000458   action: 0   reward: 0
# 52294 eepsilon: 0.9006414000000458   action: 0   reward: 0
# 52295 eepsilon: 0.9006395000000458   action: 2   reward: 0
# 52296 eepsilon: 0.9006376000000458   action: 0   reward: 0
# 52297 eepsilon: 0.9006357000000458   action: 2   reward: 0
# 52298 eepsilon: 0.9006338000000458   action: 1   reward: 0
# 52299 eepsilon: 0.9006319000000458   action: 0   reward: 0
# 52300 eepsilon: 0.9006300000000458   action: 0   reward: 0
# 52301 eepsilon: 0.9006281000000458   action: 0   reward: 0
# 52302 eepsilon: 0.9006262000000458   action: 0   reward: 0
# 52303 eepsilon: 0.9006243000000458   action: 2   reward: 0
# 52304 eepsilon: 0.9006224000000458   action: 0   reward: 0
# 52305 eepsilon: 0.9006205000000458   action: 1   reward: 0
# 52306 eepsilon: 0.9006186000000458   action: 1   reward: 0
# 52307 eepsilon: 0.9006167000000458   action: 0   reward: 0
# 52308 eepsilon: 0.9006148000000458   action: 0   reward: 0
# 52309 eepsilon: 0.9006129000000458   action: 2   reward: 0
# 52310 eepsilon: 0.9006110000000458   action: 1   reward: 0
# 52311 eepsilon: 0.9006091000000458   action: 2   reward: 0
# 52312 eepsilon: 0.9006072000000458   action: 2   reward: 0
# 52313 eepsilon: 0.9006053000000458   action: 2   reward: 0
# 52314 eepsilon: 0.9006034000000458   action: 1   reward: 0
# 52315 eepsilon: 0.9006015000000458   action: 0   reward: 0
# 52316 eepsilon: 0.9005996000000458   action: 0   reward: 0
# 52317 eepsilon: 0.9005977000000458   action: 1   reward: 0
# 52318 eepsilon: 0.9005958000000458   action: 2   reward: 0
# 52319 eepsilon: 0.9005939000000458   action: 0   reward: 0
# 52320 eepsilon: 0.9005920000000458   action: 0   reward: 0
# 52321 eepsilon: 0.9005901000000458   action: 0   reward: 0
# 52322 eepsilon: 0.9005882000000458   action: 0   reward: 0
# 52323 eepsilon: 0.9005863000000458   action: 1   reward: 0
# 52324 eepsilon: 0.9005844000000458   action: 0   reward: 0
# 52325 eepsilon: 0.9005825000000458   action: 0   reward: 0
# 52326 eepsilon: 0.9005806000000458   action: 0   reward: 0
# 52327 eepsilon: 0.9005787000000458   action: 0   reward: 0
# 52328 eepsilon: 0.9005768000000458   action: 1   reward: 0
# 52329 eepsilon: 0.9005749000000458   action: 2   reward: 0
# 52330 eepsilon: 0.9005730000000458   action: 1   reward: 0
# 52331 eepsilon: 0.9005711000000458   action: 2   reward: 0
# 52332 eepsilon: 0.9005692000000458   action: 1   reward: 0
# 52333 eepsilon: 0.9005673000000458   action: 2   reward: 0
# 52334 eepsilon: 0.9005654000000458   action: 1   reward: 0
# 52335 eepsilon: 0.9005635000000458   action: 1   reward: 0
# 52336 eepsilon: 0.9005616000000458   action: 0   reward: 0
# 52337 eepsilon: 0.9005597000000458   action: 0   reward: 0
# 52338 eepsilon: 0.9005578000000458   action: 0   reward: 0
# 52339 eepsilon: 0.9005559000000458   action: 2   reward: 0
# 52340 eepsilon: 0.9005540000000458   action: 1   reward: 0
# 52341 eepsilon: 0.9005521000000458   action: 0   reward: 0
# 52342 eepsilon: 0.9005502000000458   action: 0   reward: 0
# 52343 eepsilon: 0.9005483000000458   action: 0   reward: 0
# 52344 eepsilon: 0.9005464000000458   action: 0   reward: 0
# 52345 eepsilon: 0.9005445000000458   action: 2   reward: 0
# 52346 eepsilon: 0.9005426000000458   action: 0   reward: 0
# 52347 eepsilon: 0.9005407000000458   action: 2   reward: 0
# 52348 eepsilon: 0.9005388000000458   action: 1   reward: 0
# 52349 eepsilon: 0.9005369000000458   action: 0   reward: 0
# 52350 eepsilon: 0.9005350000000458   action: 2   reward: 0
# 52351 eepsilon: 0.9005331000000458   action: 0   reward: 0
# 52352 eepsilon: 0.9005312000000458   action: 1   reward: 0
# 52353 eepsilon: 0.9005293000000458   action: 2   reward: 0
# 52354 eepsilon: 0.9005274000000458   action: 1   reward: 0
# 52355 eepsilon: 0.9005255000000458   action: 0   reward: 0
# 52356 eepsilon: 0.9005236000000458   action: 1   reward: 0
# 52357 eepsilon: 0.9005217000000458   action: 2   reward: 0
# 52358 eepsilon: 0.9005198000000458   action: 1   reward: 0
# 52359 eepsilon: 0.9005179000000458   action: 1   reward: 0
# 52360 eepsilon: 0.9005160000000458   action: 2   reward: 0
# 52361 eepsilon: 0.9005141000000458   action: 1   reward: 0
# 52362 eepsilon: 0.9005122000000458   action: 2   reward: 0
# 52363 eepsilon: 0.9005103000000458   action: 2   reward: 0
# 52364 eepsilon: 0.9005084000000458   action: 0   reward: 0
# 52365 eepsilon: 0.9005065000000458   action: 0   reward: 0
# 52366 eepsilon: 0.9005046000000458   action: 2   reward: 0
# 52367 eepsilon: 0.9005027000000458   action: 1   reward: 0
# 52368 eepsilon: 0.9005008000000458   action: 0   reward: 0
# 52369 eepsilon: 0.9004989000000458   action: 2   reward: 0
# 52370 eepsilon: 0.9004970000000458   action: 0   reward: 0
# 52371 eepsilon: 0.9004951000000458   action: 2   reward: 0
# 52372 eepsilon: 0.9004932000000458   action: 1   reward: 0
# 52373 eepsilon: 0.9004913000000458   action: 0   reward: 0
# 52374 eepsilon: 0.9004894000000458   action: 1   reward: 0
# 52375 eepsilon: 0.9004875000000458   action: 0   reward: 0
# 52376 eepsilon: 0.9004856000000458   action: 0   reward: 0
# 52377 eepsilon: 0.9004837000000459   action: 0   reward: 0
# 52378 eepsilon: 0.9004818000000459   action: 1   reward: 0
# 52379 eepsilon: 0.9004799000000459   action: 0   reward: 0
# 52380 eepsilon: 0.9004780000000459   action: 0   reward: 0
# 52381 eepsilon: 0.9004761000000459   action: 2   reward: 0
# 52382 eepsilon: 0.9004742000000459   action: 2   reward: 0
# 52383 eepsilon: 0.9004723000000459   action: 1   reward: 0
# 52384 eepsilon: 0.9004704000000459   action: 2   reward: 0
# 52385 eepsilon: 0.9004685000000459   action: 0   reward: 0
# 52386 eepsilon: 0.9004666000000459   action: 1   reward: 0
# 52387 eepsilon: 0.9004647000000459   action: 1   reward: 0
# 52388 eepsilon: 0.9004628000000459   action: 0   reward: 0
# 52389 eepsilon: 0.9004609000000459   action: 2   reward: 0
# 52390 eepsilon: 0.9004590000000459   action: 2   reward: 0
# 52391 eepsilon: 0.9004571000000459   action: 0   reward: 0
# 52392 eepsilon: 0.9004552000000459   action: 0   reward: 0
# 52393 eepsilon: 0.9004533000000459   action: 0   reward: 0
# 52394 eepsilon: 0.9004514000000459   action: 1   reward: 0
# 52395 eepsilon: 0.9004495000000459   action: 1   reward: 0
# 52396 eepsilon: 0.9004476000000459   action: 0   reward: 0
# 52397 eepsilon: 0.9004457000000459   action: 1   reward: 0
# 52398 eepsilon: 0.9004438000000459   action: 2   reward: 0
# 52399 eepsilon: 0.9004419000000459   action: 2   reward: 0
# 52400 eepsilon: 0.9004400000000459   action: 1   reward: 0
# 52401 eepsilon: 0.9004381000000459   action: 2   reward: 0
# 52402 eepsilon: 0.9004362000000459   action: 2   reward: 0
# 52403 eepsilon: 0.9004343000000459   action: 2   reward: 0
# 52404 eepsilon: 0.9004324000000459   action: 1   reward: 0
# 52405 eepsilon: 0.9004305000000459   action: 1   reward: 0
# 52406 eepsilon: 0.9004286000000459   action: 0   reward: 0
# 52407 eepsilon: 0.9004267000000459   action: 1   reward: 0
# 52408 eepsilon: 0.9004248000000459   action: 2   reward: 0
# 52409 eepsilon: 0.9004229000000459   action: 1   reward: 0
# 52410 eepsilon: 0.9004210000000459   action: 1   reward: 0
# 52411 eepsilon: 0.9004191000000459   action: 2   reward: 0
# 52412 eepsilon: 0.9004172000000459   action: 1   reward: 0
# 52413 eepsilon: 0.9004153000000459   action: 0   reward: 0
# 52414 eepsilon: 0.9004134000000459   action: 1   reward: 0
# 52415 eepsilon: 0.9004115000000459   action: 1   reward: 0
# 52416 eepsilon: 0.9004096000000459   action: 2   reward: 0
# 52417 eepsilon: 0.9004077000000459   action: 1   reward: 0
# 52418 eepsilon: 0.9004058000000459   action: 1   reward: 0
# 52419 eepsilon: 0.9004039000000459   action: 0   reward: 0
# 52420 eepsilon: 0.9004020000000459   action: 1   reward: 0
# 52421 eepsilon: 0.9004001000000459   action: 2   reward: 0
# 52422 eepsilon: 0.9003982000000459   action: 1   reward: 0
# 52423 eepsilon: 0.9003963000000459   action: 0   reward: 0
# 52424 eepsilon: 0.9003944000000459   action: 0   reward: 0
# 52425 eepsilon: 0.9003925000000459   action: 1   reward: 0
# 52426 eepsilon: 0.9003906000000459   action: 0   reward: 0
# 52427 eepsilon: 0.9003887000000459   action: 0   reward: 0
# 52428 eepsilon: 0.9003868000000459   action: 0   reward: 0
# 52429 eepsilon: 0.9003849000000459   action: 2   reward: 0
# 52430 eepsilon: 0.9003830000000459   action: 1   reward: 0
# 52431 eepsilon: 0.9003811000000459   action: 0   reward: 0
# 52432 eepsilon: 0.9003792000000459   action: 2   reward: 0
# 52433 eepsilon: 0.9003773000000459   action: 1   reward: 0
# 52434 eepsilon: 0.9003754000000459   action: 1   reward: 0
# 52435 eepsilon: 0.9003735000000459   action: 2   reward: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a1665b308854> in <module>()
# ----> 1 train_neural_network(input_image)
#
# <ipython-input-9-8bb4b1465941> in train_neural_network(input_image)
#      71                     gt_batch.append(reward_batch[i] + LEARNING_RATE * np.max(out_batch[i]))
#      72
# ---> 73                 optimizer.run(feed_dict = {gt:gt_batch, argmax:argmax_batch, input_image:input_image_data_batch})
#      74
#      75             input_image_data = input_image_data1
#
# /home/meiming/pyenv/tensorflow3_host/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in run(self, feed_dict, session)
#    1548         none, the default session will be used.
#    1549     """
# -> 1550     _run_using_default_session(self, feed_dict, self.graph, session)
#    1551
#    1552
#
# /home/meiming/pyenv/tensorflow3_host/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _run_using_default_session(operation, feed_dict, graph, session)
#    3772                        "the operation's graph is different from the session's "
#    3773                        "graph.")
# -> 3774   session.run(operation, feed_dict)
#    3775
#    3776
#
# /home/meiming/pyenv/tensorflow3_host/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/meiming/pyenv/tensorflow3_host/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/meiming/pyenv/tensorflow3_host/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/meiming/pyenv/tensorflow3_host/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/meiming/pyenv/tensorflow3_host/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
